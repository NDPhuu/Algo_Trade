# %% [markdown]
# # Quantitative Value Strategy
# "Value investing" means investing in the stocks that are cheapest relative to common measures of business value (like earnings or assets).
#
# For this project, we're going to build an investing strategy that selects the 10 stocks with the best value metrics. From there, we will calculate recommended trades for an equal-weight portfolio of these 10 stocks.
#
# ## Library Imports

# %%
import pandas as pd
import numpy as np
import requests
import math
from vnstock3 import *
import xlsxwriter
from scipy import stats

# %%
stock = Vnstock().stock(symbol= "ACB", source='VCI')
# Out:
# 2024-09-26 23:46:56,637 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS

# %%
stocks = stock.listing.symbols_by_group('VN30')
stock_df = pd.DataFrame(stocks)
stock_df.rename(columns = {'symbol': 'Ticker'}, inplace = True)
print(stock_df)
# Out:
#    Ticker
# 0     ACB
# 1     BCM
# 2     BID
# 3     BVH
# 4     CTG
# 5     FPT
# 6     GAS
# 7     GVR
# 8     HDB
# 9     HPG
# 10    MBB
# 11    MSN
# 12    MWG
# 13    PLX
# 14    POW
# 15    SAB
# 16    SHB
# 17    SSB
# 18    SSI
# 19    STB
# 20    TCB
# 21    TPB
# 22    VCB
# 23    VHM
# 24    VIB
# 25    VIC
# 26    VJC
# 27    VNM
# 28    VPB
# 29    VRE

# %%
stock = Vnstock().stock(symbol= "CTG", source='VCI')
# P/B Ratio
pb_ratio = stock.finance.ratio(period='quarter', lang='en').iloc[0,3]
# P/E Ratio
pe_ratio = stock.finance.ratio(period = 'quarter', lang = 'en').iloc[0,6]
# P/S Ratio
ps_ratio = stock.finance.ratio(period = 'quarter', lang = 'en').iloc[0,7]
# Enterprise Value
ev = (stock.finance.balance_sheet(period='year', lang='vi').iloc[0,-6] + stock.finance.ratio(period = 'quarter', lang = 'en').iloc[0,4] 
      - stock.finance.balance_sheet(period = 'quarter', lang = 'en').iloc[0,18])
# EV/ EBITDA
ev_ebitda = stock.finance.ratio(period='year', lang='vi').iloc[0,11]
# Gross Profit 
gp = stock.finance.income_statement(period='quarter', lang='en').iloc[0,20]
pb_ratio
pe_ratio
ps_ratio
ev
ev_ebitda
# Out:
# 2024-09-27 00:32:56,987 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 0.3758402165601617

# %% [markdown]
# ## Building a Value Strategy
#
# - Các nhà đầu tư thường sử dụng một rổ số liệu định giá tổng hợp để xây dựng các chiến lược giá trị định lượng mạnh mẽ. Trong phần này, ta sẽ lọc các cổ phiếu có phân vị thấp nhất theo các số liệu sau:
#
# * Price-to-earnings ratio
# * Price-to-book ratio
# * Price-to-sales ratio
# * Enterprise Value divided by Earnings Before Interest, Taxes, Depreciation, and Amortization (EV/EBITDA)
# * Enterprise Value divided by Gross Profit (EV/GP)

# %%
rv_columns = [
    'Ticker',
    'Price',
    'Number of Shares to Buy', 
    'Price-to-Earnings Ratio',
    'PE Percentile',
    'Price-to-Book Ratio',
    'PB Percentile',
    'Price-to-Sales Ratio',
    'PS Percentile',
    'EV/EBITDA',
    'EV/EBITDA Percentile',
    'EV/GP',
    'EV/GP Percentile',
    'RV Score'
]
final_df = pd.DataFrame(columns = rv_columns)
for ticker in stock_df['Ticker']:
    try:
        price = float(stock.quote.intraday(symbol=f'{ticker}', show_log=False).iloc[0, 1])

        stock = Vnstock().stock(symbol= ticker, source='VCI')
        # P/B Ratio
        pb_ratio = stock.finance.ratio(period='quarter', lang='en').iloc[0,3]
        # P/E Ratio
        pe_ratio = stock.finance.ratio(period = 'quarter', lang = 'en').iloc[0,6]
        # P/S Ratio
        ps_ratio = stock.finance.ratio(period = 'quarter', lang = 'en').iloc[0,7]
        # Enterprise Value
        ev = (stock.finance.balance_sheet(period='year', lang='vi').iloc[0,-6] + stock.finance.ratio(period = 'quarter', lang = 'en').iloc[0,4] 
            - stock.finance.balance_sheet(period = 'quarter', lang = 'en').iloc[0,18])
        # EV/ EBITDA
        ev_ebitda = stock.finance.ratio(period='year', lang='vi').iloc[0,11]
        # Gross Profit 
        gp = stock.finance.income_statement(period='quarter', lang='en').iloc[0,20]

        ev_gp = ev/gp

        new_row = pd.Series([ticker,price, 'N/A',pe_ratio,'N/A', pb_ratio,'N/A' ,ps_ratio, 'N/A', ev_ebitda,'N/A', ev_gp,'N/A', 'N/A'], index=rv_columns)

        final_df = pd.concat([final_df, pd.DataFrame([new_row])], ignore_index=True)

    except Exception as e:
        print(f"Error with ticker {ticker}: {e}")

final_df
# Out:
# 2024-09-27 00:43:54,043 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# 2024-09-27 00:43:57,002 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:43:59,623 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:01,862 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:05,190 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:07,872 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:11,429 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:13,757 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:16,333 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:18,600 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:21,208 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:23,366 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:27,153 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:29,614 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:32,710 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:35,082 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:38,753 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:41,303 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:43,582 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:44:46,287 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:48,896 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:52,214 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:54,630 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:44:58,053 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:45:00,670 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:45:04,000 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:45:06,364 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:45:09,991 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-09-27 00:45:12,316 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 2024-09-27 00:45:14,591 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
#    Ticker     Price Number of Shares to Buy  Price-to-Earnings Ratio  \
# 0     ACB   26150.0                     N/A                 7.127993
# 1     BCM   72000.0                     N/A                28.211642
# 2     BID   50100.0                     N/A                12.481376
# 3     BVH   43400.0                     N/A                17.819479
# 4     CTG   36350.0                     N/A                 9.520017
# 5     FPT  134200.0                     N/A                27.569014
# 6     GAS   74400.0                     N/A                15.814019
# 7     GVR   36100.0                     N/A                51.917437
# 8     HDB   28100.0                     N/A                 6.553097
# 9     HPG   26150.0                     N/A                15.006368
# 10    MBB   25750.0                     N/A                 6.325365
# 11    MSN   75900.0                     N/A               154.651414
# 12    MWG   68500.0                     N/A                45.594951
# 13    PLX   45450.0                     N/A                15.770069
# 14    POW   13000.0                     N/A                28.179979
# 15    SAB   58000.0                     N/A                17.376868
# 16    SHB   10750.0                     N/A                 4.709521
# 17    SSB   16950.0                     N/A                10.076563
# 18    SSI   27550.0                     N/A                17.442726
# 19    STB   32900.0                     N/A                 7.534616
# 20    TCB   24200.0                     N/A                 7.808726
# 21    TPB   16650.0                     N/A                 8.720823
# 22    VCB   93300.0                     N/A                15.564689
# 23    VHM   44300.0                     N/A                 8.252229
# 24    VIB   19400.0                     N/A                 7.487235
# 25    VIC   42750.0                     N/A                45.997003
# 26    VJC  105000.0                     N/A                51.874650
# 27    VNM   71000.0                     N/A                15.021661
# 28    VPB   19700.0                     N/A                12.715472
# 29    VRE   19150.0                     N/A                 9.670058
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0            N/A             1.564678           N/A              3.480515
# 1            N/A             3.986727           N/A              9.201868
# 2            N/A             2.198071           N/A              3.755991
# 3            N/A             1.444996           N/A              0.806387
# 4            N/A             1.431481           N/A              2.592254
# 5            N/A             7.163126           N/A              3.406599
# 6            N/A             2.485426           N/A              1.763029
# 7            N/A             2.803232           N/A              6.254215
# 8            N/A             1.566849           N/A              2.611790
# 9            N/A             1.543480           N/A              1.257406
# 10           N/A             1.361737           N/A              2.734865
# 11           N/A             3.229123           N/A              1.358699
# 12           N/A             3.844755           N/A              0.788768
# 13           N/A             2.269111           N/A              0.199095
# 14           N/A             0.967740           N/A              1.102651
# 15           N/A             3.087094           N/A              2.359201
# 16           N/A             0.688778           N/A              1.873637
# 17           N/A             1.440484           N/A              4.207474
# 18           N/A             1.997707           N/A              6.515355
# 19           N/A             1.256095           N/A              2.311940
# 20           N/A             1.222365           N/A              3.558589
# 21           N/A             1.157424           N/A              2.344571
# 22           N/A             2.856146           N/A              7.886308
# 23           N/A             0.999890           N/A              2.464423
# 24           N/A             1.510910           N/A              2.607192
# 25           N/A             1.257078           N/A              1.168147
# 26           N/A             3.434990           N/A              0.844783
# 27           N/A             4.235147           N/A              2.345240
# 28           N/A             1.157964           N/A              2.849723
# 29           N/A             1.086919           N/A              4.169803
#
#    PS Percentile   EV/EBITDA EV/EBITDA Percentile        EV/GP  \
# 0            N/A    0.642829                  N/A -3063.679714
# 1            N/A   30.629728                  N/A  -167.440619
# 2            N/A    0.383089                  N/A    42.391573
# 3            N/A    0.045366                  N/A   110.847280
# 4            N/A    0.375840                  N/A    50.131742
# 5            N/A   16.479445                  N/A    35.663103
# 6            N/A   10.651138                  N/A    30.678203
# 7            N/A   29.029737                  N/A -1070.386767
# 8            N/A    0.453972                  N/A    99.831158
# 9            N/A   12.496115                  N/A    18.629242
# 10           N/A    0.534507                  N/A    65.221103
# 11           N/A   20.460585                  N/A    16.850717
# 12           N/A   31.757096                  N/A    12.783517
# 13           N/A   14.789208                  N/A    12.606491
# 14           N/A    8.198247                  N/A  -102.261835
# 15           N/A   15.812056                  N/A    30.511902
# 16           N/A    0.379809                  N/A   314.889434
# 17           N/A    0.520026                  N/A -1562.001239
# 18           N/A   18.777206                  N/A    67.103765
# 19           N/A    0.349696                  N/A    14.138275
# 20           N/A    0.650165                  N/A   124.582921
# 21           N/A    0.359140                  N/A    78.199734
# 22           N/A    0.616051                  N/A   155.226380
# 23           N/A    7.990757                  N/A   -71.549632
# 24           N/A    0.493248                  N/A    80.662904
# 25           N/A   23.154839                  N/A    19.829412
# 26           N/A -713.897174                  N/A   -51.956239
# 27           N/A   12.769333                  N/A    15.313735
# 28           N/A    0.261271                  N/A    84.688570
# 29           N/A    7.361331                  N/A  -219.370746
#
#    EV/GP Percentile RV Score
# 0               N/A      N/A
# 1               N/A      N/A
# 2               N/A      N/A
# 3               N/A      N/A
# 4               N/A      N/A
# 5               N/A      N/A
# 6               N/A      N/A
# 7               N/A      N/A
# 8               N/A      N/A
# 9               N/A      N/A
# 10              N/A      N/A
# 11              N/A      N/A
# 12              N/A      N/A
# 13              N/A      N/A
# 14              N/A      N/A
# 15              N/A      N/A
# 16              N/A      N/A
# 17              N/A      N/A
# 18              N/A      N/A
# 19              N/A      N/A
# 20              N/A      N/A
# 21              N/A      N/A
# 22              N/A      N/A
# 23              N/A      N/A
# 24              N/A      N/A
# 25              N/A      N/A
# 26              N/A      N/A
# 27              N/A      N/A
# 28              N/A      N/A
# 29              N/A      N/A

# %% [markdown]
# ## Calculating Value Percentiles
#
#
# * Price-to-earnings ratio
# * Price-to-book ratio
# * Price-to-sales ratio
# * EV/EBITDA
# * EV/GP

# %%
metrics = {
            'Price-to-Earnings Ratio': 'PE Percentile',
            'Price-to-Book Ratio':'PB Percentile',
            'Price-to-Sales Ratio': 'PS Percentile',
            'EV/EBITDA':'EV/EBITDA Percentile',
            'EV/GP':'EV/GP Percentile'
}

for row in final_df.index:
    for metric in metrics.keys():
        final_df.loc[row, metrics[metric]] = stats.percentileofscore(final_df[metric], final_df.loc[row, metric])/100


for metric in metrics.values():
    print(final_df[metric])
   
final_df
# Out:
# 0     0.133333
# 1     0.833333
# 2     0.433333
# 3     0.733333
# 4     0.333333
# 5     0.766667
# 6     0.633333
# 7     0.966667
# 8          0.1
# 9          0.5
# 10    0.066667
# 11         1.0
# 12    0.866667
# 13         0.6
# 14         0.8
# 15    0.666667
# 16    0.033333
# 17         0.4
# 18         0.7
# 19         0.2
# 20    0.233333
# 21         0.3
# 22    0.566667
# 23    0.266667
# 24    0.166667
# 25         0.9
# 26    0.933333
# 27    0.533333
# 28    0.466667
# 29    0.366667
# Name: PE Percentile, dtype: object
# 0     0.533333
# 1     0.933333
# 2     0.633333
# 3     0.433333
# 4     0.366667
# 5          1.0
# 6          0.7
# 7     0.733333
# 8     0.566667
# 9          0.5
# 10    0.333333
# 11    0.833333
# 12         0.9
# 13    0.666667
# 14    0.066667
# 15         0.8
# 16    0.033333
# 17         0.4
# 18         0.6
# 19    0.266667
# 20    0.233333
# 21    0.166667
# 22    0.766667
# 23         0.1
# 24    0.466667
# 25         0.3
# 26    0.866667
# 27    0.966667
# 28         0.2
# 29    0.133333
# Name: PB Percentile, dtype: object
# 0     0.733333
# 1          1.0
# 2          0.8
# 3          0.1
# 4     0.533333
# 5          0.7
# 6          0.3
# 7          0.9
# 8          0.6
# 9     0.233333
# 10    0.633333
# 11    0.266667
# 12    0.066667
# 13    0.033333
# 14    0.166667
# 15    0.466667
# 16    0.333333
# 17    0.866667
# 18    0.933333
# 19    0.366667
# 20    0.766667
# 21         0.4
# 22    0.966667
# 23         0.5
# 24    0.566667
# 25         0.2
# 26    0.133333
# 27    0.433333
# 28    0.666667
# 29    0.833333
# Name: PS Percentile, dtype: object
# 0     0.466667
# 1     0.966667
# 2     0.266667
# 3     0.066667
# 4          0.2
# 5          0.8
# 6     0.633333
# 7     0.933333
# 8          0.3
# 9     0.666667
# 10         0.4
# 11    0.866667
# 12         1.0
# 13    0.733333
# 14         0.6
# 15    0.766667
# 16    0.233333
# 17    0.366667
# 18    0.833333
# 19    0.133333
# 20         0.5
# 21    0.166667
# 22    0.433333
# 23    0.566667
# 24    0.333333
# 25         0.9
# 26    0.033333
# 27         0.7
# 28         0.1
# 29    0.533333
# Name: EV/EBITDA Percentile, dtype: object
# 0     0.033333
# 1     0.166667
# 2     0.633333
# 3          0.9
# 4     0.666667
# 5          0.6
# 6     0.566667
# 7          0.1
# 8     0.866667
# 9     0.466667
# 10         0.7
# 11    0.433333
# 12    0.333333
# 13         0.3
# 14         0.2
# 15    0.533333
# 16         1.0
# 17    0.066667
# 18    0.733333
# 19    0.366667
# 20    0.933333
# 21    0.766667
# 22    0.966667
# 23    0.233333
# 24         0.8
# 25         0.5
# 26    0.266667
# 27         0.4
# 28    0.833333
# 29    0.133333
# Name: EV/GP Percentile, dtype: object
#    Ticker     Price Number of Shares to Buy  Price-to-Earnings Ratio  \
# 0     ACB   26150.0                     N/A                 7.127993
# 1     BCM   72000.0                     N/A                28.211642
# 2     BID   50100.0                     N/A                12.481376
# 3     BVH   43400.0                     N/A                17.819479
# 4     CTG   36350.0                     N/A                 9.520017
# 5     FPT  134200.0                     N/A                27.569014
# 6     GAS   74400.0                     N/A                15.814019
# 7     GVR   36100.0                     N/A                51.917437
# 8     HDB   28100.0                     N/A                 6.553097
# 9     HPG   26150.0                     N/A                15.006368
# 10    MBB   25750.0                     N/A                 6.325365
# 11    MSN   75900.0                     N/A               154.651414
# 12    MWG   68500.0                     N/A                45.594951
# 13    PLX   45450.0                     N/A                15.770069
# 14    POW   13000.0                     N/A                28.179979
# 15    SAB   58000.0                     N/A                17.376868
# 16    SHB   10750.0                     N/A                 4.709521
# 17    SSB   16950.0                     N/A                10.076563
# 18    SSI   27550.0                     N/A                17.442726
# 19    STB   32900.0                     N/A                 7.534616
# 20    TCB   24200.0                     N/A                 7.808726
# 21    TPB   16650.0                     N/A                 8.720823
# 22    VCB   93300.0                     N/A                15.564689
# 23    VHM   44300.0                     N/A                 8.252229
# 24    VIB   19400.0                     N/A                 7.487235
# 25    VIC   42750.0                     N/A                45.997003
# 26    VJC  105000.0                     N/A                51.874650
# 27    VNM   71000.0                     N/A                15.021661
# 28    VPB   19700.0                     N/A                12.715472
# 29    VRE   19150.0                     N/A                 9.670058
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.133333             1.564678      0.533333              3.480515
# 1       0.833333             3.986727      0.933333              9.201868
# 2       0.433333             2.198071      0.633333              3.755991
# 3       0.733333             1.444996      0.433333              0.806387
# 4       0.333333             1.431481      0.366667              2.592254
# 5       0.766667             7.163126           1.0              3.406599
# 6       0.633333             2.485426           0.7              1.763029
# 7       0.966667             2.803232      0.733333              6.254215
# 8            0.1             1.566849      0.566667              2.611790
# 9            0.5             1.543480           0.5              1.257406
# 10      0.066667             1.361737      0.333333              2.734865
# 11           1.0             3.229123      0.833333              1.358699
# 12      0.866667             3.844755           0.9              0.788768
# 13           0.6             2.269111      0.666667              0.199095
# 14           0.8             0.967740      0.066667              1.102651
# 15      0.666667             3.087094           0.8              2.359201
# 16      0.033333             0.688778      0.033333              1.873637
# 17           0.4             1.440484           0.4              4.207474
# 18           0.7             1.997707           0.6              6.515355
# 19           0.2             1.256095      0.266667              2.311940
# 20      0.233333             1.222365      0.233333              3.558589
# 21           0.3             1.157424      0.166667              2.344571
# 22      0.566667             2.856146      0.766667              7.886308
# 23      0.266667             0.999890           0.1              2.464423
# 24      0.166667             1.510910      0.466667              2.607192
# 25           0.9             1.257078           0.3              1.168147
# 26      0.933333             3.434990      0.866667              0.844783
# 27      0.533333             4.235147      0.966667              2.345240
# 28      0.466667             1.157964           0.2              2.849723
# 29      0.366667             1.086919      0.133333              4.169803
#
#    PS Percentile   EV/EBITDA EV/EBITDA Percentile        EV/GP  \
# 0       0.733333    0.642829             0.466667 -3063.679714
# 1            1.0   30.629728             0.966667  -167.440619
# 2            0.8    0.383089             0.266667    42.391573
# 3            0.1    0.045366             0.066667   110.847280
# 4       0.533333    0.375840                  0.2    50.131742
# 5            0.7   16.479445                  0.8    35.663103
# 6            0.3   10.651138             0.633333    30.678203
# 7            0.9   29.029737             0.933333 -1070.386767
# 8            0.6    0.453972                  0.3    99.831158
# 9       0.233333   12.496115             0.666667    18.629242
# 10      0.633333    0.534507                  0.4    65.221103
# 11      0.266667   20.460585             0.866667    16.850717
# 12      0.066667   31.757096                  1.0    12.783517
# 13      0.033333   14.789208             0.733333    12.606491
# 14      0.166667    8.198247                  0.6  -102.261835
# 15      0.466667   15.812056             0.766667    30.511902
# 16      0.333333    0.379809             0.233333   314.889434
# 17      0.866667    0.520026             0.366667 -1562.001239
# 18      0.933333   18.777206             0.833333    67.103765
# 19      0.366667    0.349696             0.133333    14.138275
# 20      0.766667    0.650165                  0.5   124.582921
# 21           0.4    0.359140             0.166667    78.199734
# 22      0.966667    0.616051             0.433333   155.226380
# 23           0.5    7.990757             0.566667   -71.549632
# 24      0.566667    0.493248             0.333333    80.662904
# 25           0.2   23.154839                  0.9    19.829412
# 26      0.133333 -713.897174             0.033333   -51.956239
# 27      0.433333   12.769333                  0.7    15.313735
# 28      0.666667    0.261271                  0.1    84.688570
# 29      0.833333    7.361331             0.533333  -219.370746
#
#    EV/GP Percentile RV Score
# 0          0.033333      N/A
# 1          0.166667      N/A
# 2          0.633333      N/A
# 3               0.9      N/A
# 4          0.666667      N/A
# 5               0.6      N/A
# 6          0.566667      N/A
# 7               0.1      N/A
# 8          0.866667      N/A
# 9          0.466667      N/A
# 10              0.7      N/A
# 11         0.433333      N/A
# 12         0.333333      N/A
# 13              0.3      N/A
# 14              0.2      N/A
# 15         0.533333      N/A
# 16              1.0      N/A
# 17         0.066667      N/A
# 18         0.733333      N/A
# 19         0.366667      N/A
# 20         0.933333      N/A
# 21         0.766667      N/A
# 22         0.966667      N/A
# 23         0.233333      N/A
# 24              0.8      N/A
# 25              0.5      N/A
# 26         0.266667      N/A
# 27              0.4      N/A
# 28         0.833333      N/A
# 29         0.133333      N/A

# %% [markdown]
# ## Calculating the RV Score
# Bây giờ, ta sẽ tính RV Score (Robust Value), là điểm giá trị mà ta sẽ sử dụng để lọc cổ phiếu trong chiến lược này.
#
# RV Score sẽ là mean của 4 percentile scores mà ta đã tính ở phần trước.
#
# Để tính giá trị mean, chúng ta sẽ sử dụng Python's builtin statistics module.

# %%
from statistics import mean

for row in final_df.index:
    value_percentiles = []
    for metric in metrics.keys():
        value_percentiles.append(final_df.loc[row, metrics[metric]])
    final_df.loc[row, 'RV Score'] = mean(value_percentiles)
    
final_df
# Out:
#    Ticker     Price Number of Shares to Buy  Price-to-Earnings Ratio  \
# 0     ACB   26150.0                     N/A                 7.127993
# 1     BCM   72000.0                     N/A                28.211642
# 2     BID   50100.0                     N/A                12.481376
# 3     BVH   43400.0                     N/A                17.819479
# 4     CTG   36350.0                     N/A                 9.520017
# 5     FPT  134200.0                     N/A                27.569014
# 6     GAS   74400.0                     N/A                15.814019
# 7     GVR   36100.0                     N/A                51.917437
# 8     HDB   28100.0                     N/A                 6.553097
# 9     HPG   26150.0                     N/A                15.006368
# 10    MBB   25750.0                     N/A                 6.325365
# 11    MSN   75900.0                     N/A               154.651414
# 12    MWG   68500.0                     N/A                45.594951
# 13    PLX   45450.0                     N/A                15.770069
# 14    POW   13000.0                     N/A                28.179979
# 15    SAB   58000.0                     N/A                17.376868
# 16    SHB   10750.0                     N/A                 4.709521
# 17    SSB   16950.0                     N/A                10.076563
# 18    SSI   27550.0                     N/A                17.442726
# 19    STB   32900.0                     N/A                 7.534616
# 20    TCB   24200.0                     N/A                 7.808726
# 21    TPB   16650.0                     N/A                 8.720823
# 22    VCB   93300.0                     N/A                15.564689
# 23    VHM   44300.0                     N/A                 8.252229
# 24    VIB   19400.0                     N/A                 7.487235
# 25    VIC   42750.0                     N/A                45.997003
# 26    VJC  105000.0                     N/A                51.874650
# 27    VNM   71000.0                     N/A                15.021661
# 28    VPB   19700.0                     N/A                12.715472
# 29    VRE   19150.0                     N/A                 9.670058
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.133333             1.564678      0.533333              3.480515
# 1       0.833333             3.986727      0.933333              9.201868
# 2       0.433333             2.198071      0.633333              3.755991
# 3       0.733333             1.444996      0.433333              0.806387
# 4       0.333333             1.431481      0.366667              2.592254
# 5       0.766667             7.163126           1.0              3.406599
# 6       0.633333             2.485426           0.7              1.763029
# 7       0.966667             2.803232      0.733333              6.254215
# 8            0.1             1.566849      0.566667              2.611790
# 9            0.5             1.543480           0.5              1.257406
# 10      0.066667             1.361737      0.333333              2.734865
# 11           1.0             3.229123      0.833333              1.358699
# 12      0.866667             3.844755           0.9              0.788768
# 13           0.6             2.269111      0.666667              0.199095
# 14           0.8             0.967740      0.066667              1.102651
# 15      0.666667             3.087094           0.8              2.359201
# 16      0.033333             0.688778      0.033333              1.873637
# 17           0.4             1.440484           0.4              4.207474
# 18           0.7             1.997707           0.6              6.515355
# 19           0.2             1.256095      0.266667              2.311940
# 20      0.233333             1.222365      0.233333              3.558589
# 21           0.3             1.157424      0.166667              2.344571
# 22      0.566667             2.856146      0.766667              7.886308
# 23      0.266667             0.999890           0.1              2.464423
# 24      0.166667             1.510910      0.466667              2.607192
# 25           0.9             1.257078           0.3              1.168147
# 26      0.933333             3.434990      0.866667              0.844783
# 27      0.533333             4.235147      0.966667              2.345240
# 28      0.466667             1.157964           0.2              2.849723
# 29      0.366667             1.086919      0.133333              4.169803
#
#    PS Percentile   EV/EBITDA EV/EBITDA Percentile        EV/GP  \
# 0       0.733333    0.642829             0.466667 -3063.679714
# 1            1.0   30.629728             0.966667  -167.440619
# 2            0.8    0.383089             0.266667    42.391573
# 3            0.1    0.045366             0.066667   110.847280
# 4       0.533333    0.375840                  0.2    50.131742
# 5            0.7   16.479445                  0.8    35.663103
# 6            0.3   10.651138             0.633333    30.678203
# 7            0.9   29.029737             0.933333 -1070.386767
# 8            0.6    0.453972                  0.3    99.831158
# 9       0.233333   12.496115             0.666667    18.629242
# 10      0.633333    0.534507                  0.4    65.221103
# 11      0.266667   20.460585             0.866667    16.850717
# 12      0.066667   31.757096                  1.0    12.783517
# 13      0.033333   14.789208             0.733333    12.606491
# 14      0.166667    8.198247                  0.6  -102.261835
# 15      0.466667   15.812056             0.766667    30.511902
# 16      0.333333    0.379809             0.233333   314.889434
# 17      0.866667    0.520026             0.366667 -1562.001239
# 18      0.933333   18.777206             0.833333    67.103765
# 19      0.366667    0.349696             0.133333    14.138275
# 20      0.766667    0.650165                  0.5   124.582921
# 21           0.4    0.359140             0.166667    78.199734
# 22      0.966667    0.616051             0.433333   155.226380
# 23           0.5    7.990757             0.566667   -71.549632
# 24      0.566667    0.493248             0.333333    80.662904
# 25           0.2   23.154839                  0.9    19.829412
# 26      0.133333 -713.897174             0.033333   -51.956239
# 27      0.433333   12.769333                  0.7    15.313735
# 28      0.666667    0.261271                  0.1    84.688570
# 29      0.833333    7.361331             0.533333  -219.370746
#
#    EV/GP Percentile  RV Score
# 0          0.033333      0.38
# 1          0.166667      0.78
# 2          0.633333  0.553333
# 3               0.9  0.446667
# 4          0.666667      0.42
# 5               0.6  0.773333
# 6          0.566667  0.566667
# 7               0.1  0.726667
# 8          0.866667  0.486667
# 9          0.466667  0.473333
# 10              0.7  0.426667
# 11         0.433333      0.68
# 12         0.333333  0.633333
# 13              0.3  0.466667
# 14              0.2  0.366667
# 15         0.533333  0.646667
# 16              1.0  0.326667
# 17         0.066667      0.42
# 18         0.733333      0.76
# 19         0.366667  0.266667
# 20         0.933333  0.533333
# 21         0.766667      0.36
# 22         0.966667      0.74
# 23         0.233333  0.333333
# 24              0.8  0.466667
# 25              0.5      0.56
# 26         0.266667  0.446667
# 27              0.4  0.606667
# 28         0.833333  0.453333
# 29         0.133333       0.4

# %% [markdown]
# ## Selecting the 10 Best Value Stocks¶

# %%
final_df.sort_values(by = 'RV Score', inplace = True)
final_df = final_df[:10]
final_df.reset_index(drop = True, inplace = True)

# %% [markdown]
# ## Calculating the Number of Shares to Buy

# %%
def portfolio_input():
    global portfolio_size
    portfolio_size = input("Nhập giá trị danh mục:")

    try:
        val = float(portfolio_size)
    except ValueError:
        print("Invalid \n Try again:")
        portfolio_size = input("Nhập giá trị danh mục:")

# %%
portfolio_input()

# %%
position_size = float(portfolio_size) / len(final_df.index)
for i in range(0, len(final_df['Ticker'])):
    final_df.loc[i, 'Number of Shares to Buy'] = math.floor(position_size / final_df['Price'][i])
final_df
# Out:
#   Ticker    Price Number of Shares to Buy  Price-to-Earnings Ratio  \
# 0    STB  32900.0                      30                 7.534616
# 1    SHB  10750.0                      93                 4.709521
# 2    VHM  44300.0                      22                 8.252229
# 3    TPB  16650.0                      60                 8.720823
# 4    POW  13000.0                      76                28.179979
# 5    ACB  26150.0                      38                 7.127993
# 6    VRE  19150.0                      52                 9.670058
# 7    CTG  36350.0                      27                 9.520017
# 8    SSB  16950.0                      58                10.076563
# 9    MBB  25750.0                      38                 6.325365
#
#   PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0           0.2             1.256095      0.266667              2.311940
# 1      0.033333             0.688778      0.033333              1.873637
# 2      0.266667             0.999890           0.1              2.464423
# 3           0.3             1.157424      0.166667              2.344571
# 4           0.8             0.967740      0.066667              1.102651
# 5      0.133333             1.564678      0.533333              3.480515
# 6      0.366667             1.086919      0.133333              4.169803
# 7      0.333333             1.431481      0.366667              2.592254
# 8           0.4             1.440484           0.4              4.207474
# 9      0.066667             1.361737      0.333333              2.734865
#
#   PS Percentile  EV/EBITDA EV/EBITDA Percentile        EV/GP EV/GP Percentile  \
# 0      0.366667   0.349696             0.133333    14.138275         0.366667
# 1      0.333333   0.379809             0.233333   314.889434              1.0
# 2           0.5   7.990757             0.566667   -71.549632         0.233333
# 3           0.4   0.359140             0.166667    78.199734         0.766667
# 4      0.166667   8.198247                  0.6  -102.261835              0.2
# 5      0.733333   0.642829             0.466667 -3063.679714         0.033333
# 6      0.833333   7.361331             0.533333  -219.370746         0.133333
# 7      0.533333   0.375840                  0.2    50.131742         0.666667
# 8      0.866667   0.520026             0.366667 -1562.001239         0.066667
# 9      0.633333   0.534507                  0.4    65.221103              0.7
#
#    RV Score
# 0  0.266667
# 1  0.326667
# 2  0.333333
# 3      0.36
# 4  0.366667
# 5      0.38
# 6       0.4
# 7      0.42
# 8      0.42
# 9  0.426667
